# %%
import sys

print(sys.version)
# Out:
# 3.12.9 (tags/v3.12.9:fdb8142, Feb  4 2025, 15:27:58) [MSC v.1942 64 bit (AMD64)]

# %%
if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
print("Ahmed") ; print("AI Engineer"); print("Age=20")
# Out:
# Ahmed
# AI Engineer
# Age=20

# %%
print('Alahly')
# Out:
# Alahly

# %%
print("Ahmed AI Engineer", end=" ")
print("Age=20")
# Out:
# Ahmed AI Engineer Age=20

# %%
print("I'm Ahmed AI Engineer" , 20 ,"Years old")
# Out:
# I'm Ahmed AI Engineer 20 Years old

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
name="Ahmed"
job="AI Engineer"
age=20 
print(name,job,age)
# Out:
# Ahmed AI Engineer 20

# %%
name="Ahmed"
job="AI Engineer"
age=20 
print(type (name))
print(type (job))
print(type (age))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# Orange
# Banana
# Cherry
# Orange Banana Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# Orange
# Orange
# Orange
# Orange Orange Orange

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x,y,z)
# Out:
# Python  is  awesome

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
x = "Cristiano Ronlado "

def myfunc():
  print( x+"is the GOAT " )

myfunc()
# Out:
# Cristiano Ronlado is the GOAT

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
print(x)
print(y)
print(z)
# Out:
# 1.0
# 2.8
# 3.0

# %%
x = str("s1") # x will be 's1'
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a = "Hello, World!"
print(a[0],a[1])
# Out:
# H e

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %%
b = "Ahmed, Salah!"
print(b[0],b[7])
# Out:
# A S

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = "Hello, World!"
print(a.upper())
b= "Hello, World!"
print(b.lower())
# Out:
# HELLO, WORLD!
# hello, world!

# %%
a = " Hello, World! "
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]

print(x is y)
# Out:
# False

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
